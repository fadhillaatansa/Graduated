# %% [markdown]
# <a href="https://colab.research.google.com/github/fadhillaatansa/Graduated/blob/main/DhillaSarjana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_play_scraper
# Out:
# ...
#      |████████████████████████████████| 51kB 2.6MB/s
# ...
#   Created wheel for google-play-scraper: filename=google_play_scraper-0.1.2-cp36-none-any.whl size=22280 sha256=a0ed822409995525062e2d83f2e9a59b7b9b260471763ae3f838acd8d95f6723
#   Stored in directory: /root/.cache/pip/wheels/c3/0c/dc/847f7da787b7d2c28b26a5062f86eac3f16a8cb0bdfdc1f308
# Successfully built google-play-scraper
# ...

# %%
pip install google_play_scraper

# %%
import json

# %%
from google_play_scraper.constants.element import ElementSpecs
from google_play_scraper.constants.regex import Regex
from google_play_scraper.constants.request import Formats
from google_play_scraper.utils.request import get

# %%
from google_play_scraper import app

result = app(
    'com.valar.pintu',
    lang='id',
    country='id',
)

# %%
result, continuation_token = reviews(
    'com.valar.pintu',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
)

result, _ = reviews(
    'com.valar.pintu',
    continuation_token=continuation_token
)

# %%
result
# Out:
# [{'at': datetime.datetime(2020, 10, 9, 6, 35, 19),
#   'content': 'Bagus tapi perlu di tingkatkan lagi terutama Bug. Sama verifikasinya. Sama sdh mendaftar 2 hari tapi belum terverifikasi sama sekali...mohon dpt di percepat.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '2.6.0',
#   'reviewId': 'gp:AOqpTOE6yhTZZvKJzefxsl5ozTFi8WqL1mLOMlWOqXEpqM-kE8e8ZrhaEUT19auzLJra5vWasa1qpAPUshXG8Q',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gjpd9R6RpgP5TaapnwqlHmIZf3TWlLVvTplUN8YPg',
#   'userName': 'axel mokoagow'},
#  {'at': datetime.datetime(2020, 10, 5, 23, 43, 21),
#   'content': 'Ini awalnya lancar, cuma semakin lama mau login gak bisa kena kode 504... Maksud nya apa yaa?? Pemulihan email jwb nya tetap sama kode 504',
#   'repliedAt': datetime.datetime(2020, 10, 8, 12, 43, 45),
# ...

# %%
# !git clone https://github.com/fadhillaatansa/Graduated.git
# Out:
# Cloning into 'Graduated'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
print(result)
# Out:
# [{'reviewId': 'gp:AOqpTOE6yhTZZvKJzefxsl5ozTFi8WqL1mLOMlWOqXEpqM-kE8e8ZrhaEUT19auzLJra5vWasa1qpAPUshXG8Q', 'userName': 'axel mokoagow', 'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gjpd9R6RpgP5TaapnwqlHmIZf3TWlLVvTplUN8YPg', 'content': 'Bagus tapi perlu di tingkatkan lagi terutama Bug. Sama verifikasinya. Sama sdh mendaftar 2 hari tapi belum terverifikasi sama sekali...mohon dpt di percepat.', 'score': 5, 'thumbsUpCount': 3, 'reviewCreatedVersion': '2.6.0', 'at': datetime.datetime(2020, 10, 9, 6, 35, 19), 'replyContent': None, 'repliedAt': None}, {'reviewId': 'gp:AOqpTOHgrP6hhLdJUnrH73r9V_9K-yYMHJDm3n3-2fZ1nHVlpsrWus7E5KscvnRypenV_N8kK8cj8JP2Uc-KKg', 'userName': 'Darul Sudariani', 'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh3N_hky2YD5xIMy8s6yPrr1dH5nDEQO2Ph2_wDXg', 'content': 'Ini awalnya lancar, cuma semakin lama mau login gak bisa kena kode 504... Maksud nya apa yaa?? Pemulihan email jwb nya tetap sama kode 504', 'score': 1, 'thumbsUpCount': 3, 'rev
# ...
